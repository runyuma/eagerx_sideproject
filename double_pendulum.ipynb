# %% [markdown]
# # 1. define eager graph

# %%
import eagerx
from typing import Dict
import numpy as np
from huggingface_sb3 import load_from_hub
import stable_baselines3 as sb3

from double_pendulum.objects import Double_Pendulum

# %%
# noinspection JupyterPackage
rate = 20.0
graph = eagerx.Graph.create()
sensors = ["theta", "theta_dot", "image"]
actuators = ["u"]
states = ["model_state"]
pendulum = Double_Pendulum.make("double_pendulum", rate=rate, actuators=actuators, sensors=sensors, states=states, render_fn="double_pendulum_render_fn")

from double_pendulum.processor import DecomposedAngle,DecomposedAngle_vel
pendulum.sensors.theta.processor = DecomposedAngle.make()
pendulum.sensors.theta.space.low = -1
pendulum.sensors.theta.space.high = 1
pendulum.sensors.theta.space.shape = [4]
pendulum.sensors.theta_dot.processor = DecomposedAngle_vel.make()
pendulum.sensors.theta_dot.space.low = -999
pendulum.sensors.theta_dot.space.high = 999
pendulum.sensors.theta_dot.space.shape = [2]


graph.add(pendulum)

# Connect the pendulum to an action and observations
graph.connect(action="voltage", target=pendulum.actuators.u)
graph.connect(source=pendulum.sensors.theta, observation="angle")
graph.connect(source=pendulum.sensors.theta_dot, observation="angular_velocity")

# Render image
graph.render(source=pendulum.sensors.image, rate=rate)
Double_Pendulum.info()
# Out:
#    entity_type: `Double_Pendulum`
#    module: `double_pendulum.objects`
#    file: `/home/marunyu/study/eagerx_sideproject/double_pendulum/objects.py`
#
# Supported engines:
#  - eagerx_ode.engine/OdeEngine
#
# Make this spec with:
#    spec = Double_Pendulum.make(name: str, actuators: List[str] = None, sensors: List[str] = None, states: List[str] = None, rate: float = 30.0, render_shape: List[int] = None, render_fn: str = None)
#
# class Double_Pendulum:
#    make(name: str, actuators: List[str] = None, sensors: List[str] = None, states: List[str] = None, rate: float = 30.0, render_shape: List[int] = None, render_fn: str = None):
#       sensors:
#        - theta: Space(-999.0, 999.0, (), float32)
#        - theta_dot: Space(-999.0, 999.0, (), float32)
#        - image: Space(uint8)
#        - u_applied: Space([-4.], [4.], (1,), float32)
#       actuators:
#        - u: Space([-4.], [4.], (1,), float32)
#       engine_states:
#        - model_state: Space([-3.14 -3.14 -9.   -9.  ], [3.14 3.14 9.   9.  ], (4,), float32)
#        - model_parameters: Space(float32)
#        - mass: Space(0.800000011920929, 1.25, (), float32)
#        - length: Space(0.30000001192092896, 0.5, (), float32)
#        - max_speed: Space(22.0, 22.0, (), float32)
#       docs: <Not available>

# %% [markdown]
# engine and train environment

# %%
from eagerx_ode.engine import OdeEngine
from double_pendulum.double_pendulum_env import Double_PendulumEnv
from gym.wrappers.rescale_action import RescaleAction
ode_engine = OdeEngine.make(rate=rate)
train_env = Double_PendulumEnv(name="train", rate=rate, graph=graph, engine=ode_engine, eval=False)
test_env = Double_PendulumEnv(name="test", rate=rate, graph=graph, engine=ode_engine, eval=True)
print("action_space: ", train_env.action_space)
print("observation_space: ", train_env.observation_space)
# ode_render = pendulum.gui(OdeEngine)
from eagerx.wrappers import Flatten
from stable_baselines3.common.env_checker import check_env
train_env = Flatten(train_env)
test_env = Flatten(test_env)
# Out:
# [WARN]: Backend 'SINGLE_PROCESS' does not support multiprocessing, so all nodes are launched in the ENVIRONMENT process.
# action_space:  Dict(voltage:Space([-4.], [4.], (1,), float32))
# observation_space:  Dict(angle:Box([[-1. -1. -1. -1.]], [[1. 1. 1. 1.]], (1, 4), float32), angular_velocity:Box([[-999. -999.]], [[999. 999.]], (1, 2), float32))

# %% [markdown]
# # 2 train

# %% [markdown]
# # 2.1 SAC

# %%
sac_model = sb3.SAC("MlpPolicy", train_env, verbose=1, learning_rate=7e-4, tensorboard_log="./tensorboard/sac_doupen_tensorboard/")
train_env.render("human")
sac_model.learn(total_timesteps=int(10000))
train_env.close()
sac_model.save("./model/double_pendulum_sac")
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to ./tensorboard/sac_doupen_tensorboard/SAC_12
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
#
# QObject::moveToThread: Current thread (0x7f24d8001930) is not the object's thread (0x7f24d80d1570).
# Cannot move to target thread (0x7f24d8001930)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 sac_model = sb3.SAC("MlpPolicy", train_env, verbose=1, learning_rate=7e-4, tensorboard_log="./tensorboard/sac_doupen_tensorboard/")
#       2 train_env.render("human")
# ----> 3 sac_model.learn(total_timesteps=int(10000))
#       4 train_env.close()
#       5 sac_model.save("./model/double_pendulum_sac")
#
# File ~/.cache/pypoetry/virtualenvs/eagerx-izmxb-y5-py3.9/lib/python3.9/site-packages/stable_baselines3/sac/sac.py:309, in SAC.learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps, progress_bar)
#     295 def learn(
#     296     self: SACSelf,
#     297     total_timesteps: int,
#    (...)
#     306     progress_bar: bool = False,
#     307 ) -> SACSelf:
# --> 309     return super().learn(
#     310         total_timesteps=total_timesteps,
#     311         callback=callback,
#     312         log_interval=log_interval,
#     313         eval_env=eval_env,
#     314         eval_freq=eval_freq,
#     315         n_eval_episodes=n_eval_episodes,
#     316         tb_log_name=tb_log_name,
#     317         eval_log_path=eval_log_path,
#     318         reset_num_timesteps=reset_num_timesteps,
#     319         progress_bar=progress_bar,
#     320     )
#
# File ~/.cache/pypoetry/virtualenvs/eagerx-izmxb-y5-py3.9/lib/python3.9/site-packages/stable_baselines3/common/off_policy_algorithm.py:356, in OffPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps, progress_bar)
#     353 callback.on_training_start(locals(), globals())
#     355 while self.num_timesteps < total_timesteps:
# --> 356     rollout = self.collect_rollouts(
#     357         self.env,
#     358         train_freq=self.train_freq,
#     359         action_noise=self.action_noise,
#     360         callback=callback,
#     361         learning_starts=self.learning_starts,
#     362         replay_buffer=self.replay_buffer,
#     363         log_interval=log_interval,
#     364     )
#     366     if rollout.continue_training is False:
#     367         break
#
# File ~/.cache/pypoetry/virtualenvs/eagerx-izmxb-y5-py3.9/lib/python3.9/site-packages/stable_baselines3/common/off_policy_algorithm.py:589, in OffPolicyAlgorithm.collect_rollouts(self, env, callback, train_freq, replay_buffer, action_noise, learning_starts, log_interval)
#     586 actions, buffer_actions = self._sample_action(learning_starts, action_noise, env.num_envs)
#     588 # Rescale and perform action
# --> 589 new_obs, rewards, dones, infos = env.step(actions)
#     591 self.num_timesteps += env.num_envs
#     592 num_collected_steps += 1
#
# File ~/.cache/pypoetry/virtualenvs/eagerx-izmxb-y5-py3.9/lib/python3.9/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:162, in VecEnv.step(self, actions)
#     155 """
#     156 Step the environments with the given action
#     157
#     158 :param actions: the action
#     159 :return: observation, reward, done, information
#     160 """
#     161 self.step_async(actions)
# --> 162 return self.step_wait()
#
# File ~/.cache/pypoetry/virtualenvs/eagerx-izmxb-y5-py3.9/lib/python3.9/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py:43, in DummyVecEnv.step_wait(self)
#      41 def step_wait(self) -> VecEnvStepReturn:
#      42     for env_idx in range(self.num_envs):
# ---> 43         obs, self.buf_rews[env_idx], self.buf_dones[env_idx], self.buf_infos[env_idx] = self.envs[env_idx].step(
#      44             self.actions[env_idx]
#      45         )
#      46         if self.buf_dones[env_idx]:
#      47             # save final observation where user can get it, then reset
#      48             self.buf_infos[env_idx]["terminal_observation"] = obs
#
# File ~/.cache/pypoetry/virtualenvs/eagerx-izmxb-y5-py3.9/lib/python3.9/site-packages/stable_baselines3/common/monitor.py:94, in Monitor.step(self, action)
#      92 if self.needs_reset:
#      93     raise RuntimeError("Tried to step environment that needs reset")
# ---> 94 observation, reward, done, info = self.env.step(action)
#      95 self.rewards.append(reward)
#      96 if done:
#
# File ~/.cache/pypoetry/virtualenvs/eagerx-izmxb-y5-py3.9/lib/python3.9/site-packages/gym/core.py:289, in Wrapper.step(self, action)
#     288 def step(self, action):
# --> 289     return self.env.step(action)
#
# File ~/.cache/pypoetry/virtualenvs/eagerx-izmxb-y5-py3.9/lib/python3.9/site-packages/gym/core.py:323, in ObservationWrapper.step(self, action)
#     322 def step(self, action):
# --> 323     observation, reward, done, info = self.env.step(action)
#     324     return self.observation(observation), reward, done, info
#
# File ~/.cache/pypoetry/virtualenvs/eagerx-izmxb-y5-py3.9/lib/python3.9/site-packages/gym/core.py:349, in ActionWrapper.step(self, action)
#     348 def step(self, action):
# --> 349     return self.env.step(self.action(action))
#
# File ~/study/eagerx_sideproject/double_pendulum/double_pendulum_env.py:44, in Double_PendulumEnv.step(self, action)
#      30 """A method that runs one timestep of the environment's dynamics.
#      31
#      32 :params action: A dictionary of actions provided by the agent.
#    (...)
#      41     - info: contains auxiliary diagnostic information (helpful for debugging, and sometimes learning)
#      42 """
#      43 # Take step
# ---> 44 observation = self._step(action)
#      45 self.steps += 1
#      47 # Extract observations
#
# File ~/study/sideproject/eagerx/eagerx/core/env.py:389, in BaseEnv._step(self, action)
#     386 self._set_action(action)
#     388 # Call step
# --> 389 self.supervisor.step()
#     390 return self._get_observation()
#
# File ~/study/sideproject/eagerx/eagerx/core/supervisor.py:107, in SupervisorNode.step(self)
#     105 self._step_counter += 1
#     106 try:
# --> 107     flag = self.env_node.obs_event.wait()
#     108     if not flag:
#     109         raise KeyboardInterrupt
#
# File ~/anaconda3/lib/python3.9/threading.py:581, in Event.wait(self, timeout)
#     579 signaled = self._flag
#     580 if not signaled:
# --> 581     signaled = self._cond.wait(timeout)
#     582 return signaled
#
# File ~/anaconda3/lib/python3.9/threading.py:312, in Condition.wait(self, timeout)
#     310 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     311     if timeout is None:
# --> 312         waiter.acquire()
#     313         gotit = True
#     314     else:
#
# KeyboardInterrupt:

# %%
from stable_baselines3.common.evaluation import evaluate_policy
# sac_model = sb3.SAC.load("./model/double_pendulum_sac.zip")
sac_model = sb3.SAC.load("./double_pendulum_sac.zip")
mean_reward, std_reward = evaluate_policy(sac_model, test_env, n_eval_episodes=10, render=True)
print("mean_reward:",mean_reward,"std_reward:",std_reward)
# Out:
# /home/marunyu/.cache/pypoetry/virtualenvs/eagerx-izmxb-y5-py3.9/lib/python3.9/site-packages/stable_baselines3/common/evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
#
# QObject::moveToThread: Current thread (0x7f24dc0019c0) is not the object's thread (0x7f24dc100c50).
# Cannot move to target thread (0x7f24dc0019c0)
# reward: 97.38063159402375
# reward: 95.95907044266751
# reward: 93.25270033367876
# reward: 90.78136028438419
# reward: 93.361631543897
# reward: 92.68520005555807
# reward: 92.77249300220618
# reward: 94.3985243141767
# reward: 93.12875050517955
# reward: 95.3325056754544
# reward: 81.96444041758139
# reward: 76.00945084014957
# reward: 94.41517933105
# reward: 92.15052833761834
# reward: 92.200313852986
# reward: 92.93450090595188
# reward: 92.66680952803739
# reward: 94.29514461445157
# reward: 92.90853695224784
# reward: 98.51368341639066
# reward: 97.03153166290186
# reward: 93.88636577785967
# reward: 91.17595833887212
# reward: 92.62289639023625
# reward: 92.94377759110391
# reward: 92.65619758100206
# reward: 94.31076246891752
# reward: 92.94470619331098
# reward: 96.35078434486596
# reward: 76.25136457732317
# reward: 94.38307468343584
# reward: 91.96682123126355
# reward: 92.16779189088308
# reward: 92.83517960932309
# reward: 92.69570251311096
# reward: 94.30735140831386
# reward: 92.93654363638983
# reward: 95.92714045289813
# reward: 79.66427721917361
# reward: 78.57985378145229
# reward: 93.4320280263836
# reward: 92.70333931941273
# reward: 92.72309695086648
# reward: 92.79129334332018
# reward: 94.41057317100568
# reward: 93.15340671028672
# reward: 94.70493797358883
# reward: 81.16292463915656
# reward: 77.4739484763407
# reward: 94.13321604724986
# reward: 91.12151585251912
# reward: 92.12682539837344
# reward: 92.90502749296913
# reward: 94.26304039776275
# reward: 92.83214171405307
# reward: 94.47030911434472
# reward: 93.27884493988067
# reward: 96.71987399382729
# reward: 79.67953371171096
# reward: 79.46086413465393
# reward: 93.49907120481035
# reward: 92.67156926983596
# reward: 92.72899663596594
# reward: 92.78867478185455
# reward: 94.41073253476983
# reward: 93.15374870700882
# reward: 91.26819702725089
# reward: 88.12919211358424
# reward: 93.67014169737769
# reward: 92.56003104034933
# reward: 92.75391925086495
# reward: 94.2573559166172
# reward: 92.80958449515963
# reward: 94.43597798953216
# reward: 93.20492254151449
# reward: 93.13884478093827
# reward: 89.61405323968442
# reward: 92.68608595532294
# reward: 92.9329834620623
# reward: 92.65861489374612
# reward: 94.30658346720638
# reward: 92.93508709729363
# reward: 94.47283618980036
# reward: 93.28449651213329
# reward: 96.45284652447081
# reward: 81.89473938848333
# reward: 76.7821386518083
# reward: 94.43087743304447
# reward: 92.2757081800262
# reward: 92.5959304675232
# reward: 92.99924266367522
# reward: 92.64153109829823
# reward: 94.3338549836393
# reward: 92.99274395710061
# mean_reward: -9051.240028681234 std_reward: 370.5389623673038

# %% [markdown]
# # 2.2 DDPG

# %%
ddpg_model = sb3.DDPG("MlpPolicy", train_env, verbose=1, learning_rate=5e-4, tensorboard_log="./tensorboard/ddpg_doupen_tensorboard/")
train_env.render("human")
ddpg_model.learn(total_timesteps=int(10000))
train_env.close()
ddpg_model.save("./model/double_pendulum_ddpg")
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to ./tensorboard/ddpg_doupen_tensorboard/DDPG_3
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
#
# QObject::moveToThread: Current thread (0x7f46c40019b0) is not the object's thread (0x7f46c41291c0).
# Cannot move to target thread (0x7f46c40019b0)
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 101       |
# |    ep_rew_mean     | -1.04e+04 |
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 77        |
# |    time_elapsed    | 5         |
# |    total_timesteps | 404       |
# | train/             |           |
# |    actor_loss      | 127       |
# |    critic_loss     | 1.73e+03  |
# |    learning_rate   | 0.0005    |
# |    n_updates       | 303       |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 101       |
# |    ep_rew_mean     | -1.03e+04 |
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 89        |
# |    time_elapsed    | 9         |
# |    total_timesteps | 808       |
# | train/             |           |
# |    actor_loss      | 288       |
# |    critic_loss     | 633       |
# |    learning_rate   | 0.0005    |
# |    n_updates       | 707       |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 101       |
# |    ep_rew_mean     | -1.01e+04 |
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 94        |
# |    time_elapsed    | 12        |
# |    total_timesteps | 1212      |
# | train/             |           |
# |    actor_loss      | 445       |
# |    critic_loss     | 857       |
# |    learning_rate   | 0.0005    |
# |    n_updates       | 1111      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 101       |
# |    ep_rew_mean     | -9.39e+03 |
# | time/              |           |
# |    episodes        | 16        |
# |    fps             | 97        |
# |    time_elapsed    | 16        |
# |    total_timesteps | 1616      |
# | train/             |           |
# |    actor_loss      | 579       |
# |    critic_loss     | 607       |
# |    learning_rate   | 0.0005    |
# |    n_updates       | 1515      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 101       |
# |    ep_rew_mean     | -8.83e+03 |
# | time/              |           |
# |    episodes        | 20        |
# |    fps             | 98        |
# |    time_elapsed    | 20        |
# |    total_timesteps | 2020      |
# | train/             |           |
# |    actor_loss      | 683       |
# |    critic_loss     | 412       |
# |    learning_rate   | 0.0005    |
# |    n_updates       | 1919      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 101       |
# |    ep_rew_mean     | -8.49e+03 |
# | time/              |           |
# |    episodes        | 24        |
# |    fps             | 96        |
# |    time_elapsed    | 25        |
# |    total_timesteps | 2424      |
# | train/             |           |
# |    actor_loss      | 781       |
# |    critic_loss     | 279       |
# |    learning_rate   | 0.0005    |
# |    n_updates       | 2323      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 101       |
# |    ep_rew_mean     | -8.19e+03 |
# | time/              |           |
# |    episodes        | 28        |
# |    fps             | 97        |
# |    time_elapsed    | 29        |
# |    total_timesteps | 2828      |
# | train/             |           |
# |    actor_loss      | 867       |
# |    critic_loss     | 207       |
# |    learning_rate   | 0.0005    |
# |    n_updates       | 2727      |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -8e+03   |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 97       |
# |    time_elapsed    | 33       |
# |    total_timesteps | 3232     |
# | train/             |          |
# |    actor_loss      | 948      |
# |    critic_loss     | 199      |
# |    learning_rate   | 0.0005   |
# |    n_updates       | 3131     |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 101       |
# |    ep_rew_mean     | -7.82e+03 |
# | time/              |           |
# |    episodes        | 36        |
# |    fps             | 98        |
# |    time_elapsed    | 36        |
# |    total_timesteps | 3636      |
# | train/             |           |
# |    actor_loss      | 1.02e+03  |
# |    critic_loss     | 190       |
# |    learning_rate   | 0.0005    |
# |    n_updates       | 3535      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 101       |
# |    ep_rew_mean     | -7.69e+03 |
# | time/              |           |
# |    episodes        | 40        |
# |    fps             | 98        |
# |    time_elapsed    | 41        |
# |    total_timesteps | 4040      |
# | train/             |           |
# |    actor_loss      | 1.09e+03  |
# |    critic_loss     | 206       |
# |    learning_rate   | 0.0005    |
# |    n_updates       | 3939      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 101       |
# |    ep_rew_mean     | -7.57e+03 |
# | time/              |           |
# |    episodes        | 44        |
# |    fps             | 98        |
# |    time_elapsed    | 45        |
# |    total_timesteps | 4444      |
# | train/             |           |
# |    actor_loss      | 1.17e+03  |
# |    critic_loss     | 204       |
# |    learning_rate   | 0.0005    |
# |    n_updates       | 4343      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 101       |
# |    ep_rew_mean     | -7.43e+03 |
# | time/              |           |
# |    episodes        | 48        |
# |    fps             | 98        |
# |    time_elapsed    | 49        |
# |    total_timesteps | 4848      |
# | train/             |           |
# |    actor_loss      | 1.24e+03  |
# |    critic_loss     | 178       |
# |    learning_rate   | 0.0005    |
# |    n_updates       | 4747      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 101       |
# |    ep_rew_mean     | -7.34e+03 |
# | time/              |           |
# |    episodes        | 52        |
# |    fps             | 98        |
# |    time_elapsed    | 53        |
# |    total_timesteps | 5252      |
# | train/             |           |
# |    actor_loss      | 1.31e+03  |
# |    critic_loss     | 172       |
# |    learning_rate   | 0.0005    |
# |    n_updates       | 5151      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 101       |
# |    ep_rew_mean     | -7.28e+03 |
# | time/              |           |
# |    episodes        | 56        |
# |    fps             | 98        |
# |    time_elapsed    | 57        |
# |    total_timesteps | 5656      |
# | train/             |           |
# |    actor_loss      | 1.39e+03  |
# |    critic_loss     | 170       |
# |    learning_rate   | 0.0005    |
# |    n_updates       | 5555      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 101       |
# |    ep_rew_mean     | -7.22e+03 |
# | time/              |           |
# |    episodes        | 60        |
# |    fps             | 99        |
# |    time_elapsed    | 61        |
# |    total_timesteps | 6060      |
# | train/             |           |
# |    actor_loss      | 1.47e+03  |
# |    critic_loss     | 154       |
# |    learning_rate   | 0.0005    |
# |    n_updates       | 5959      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 101       |
# |    ep_rew_mean     | -7.16e+03 |
# | time/              |           |
# |    episodes        | 64        |
# |    fps             | 99        |
# |    time_elapsed    | 65        |
# |    total_timesteps | 6464      |
# | train/             |           |
# |    actor_loss      | 1.55e+03  |
# |    critic_loss     | 160       |
# |    learning_rate   | 0.0005    |
# |    n_updates       | 6363      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 101       |
# |    ep_rew_mean     | -7.12e+03 |
# | time/              |           |
# |    episodes        | 68        |
# |    fps             | 99        |
# |    time_elapsed    | 69        |
# |    total_timesteps | 6868      |
# | train/             |           |
# |    actor_loss      | 1.62e+03  |
# |    critic_loss     | 154       |
# |    learning_rate   | 0.0005    |
# |    n_updates       | 6767      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 101       |
# |    ep_rew_mean     | -7.06e+03 |
# | time/              |           |
# |    episodes        | 72        |
# |    fps             | 99        |
# |    time_elapsed    | 73        |
# |    total_timesteps | 7272      |
# | train/             |           |
# |    actor_loss      | 1.69e+03  |
# |    critic_loss     | 142       |
# |    learning_rate   | 0.0005    |
# |    n_updates       | 7171      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 101       |
# |    ep_rew_mean     | -7.03e+03 |
# | time/              |           |
# |    episodes        | 76        |
# |    fps             | 99        |
# |    time_elapsed    | 77        |
# |    total_timesteps | 7676      |
# | train/             |           |
# |    actor_loss      | 1.77e+03  |
# |    critic_loss     | 147       |
# |    learning_rate   | 0.0005    |
# |    n_updates       | 7575      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 101       |
# |    ep_rew_mean     | -7.01e+03 |
# | time/              |           |
# |    episodes        | 80        |
# |    fps             | 99        |
# |    time_elapsed    | 81        |
# |    total_timesteps | 8080      |
# | train/             |           |
# |    actor_loss      | 1.84e+03  |
# |    critic_loss     | 127       |
# |    learning_rate   | 0.0005    |
# |    n_updates       | 7979      |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -7e+03   |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 99       |
# |    time_elapsed    | 84       |
# |    total_timesteps | 8484     |
# | train/             |          |
# |    actor_loss      | 1.91e+03 |
# |    critic_loss     | 131      |
# |    learning_rate   | 0.0005   |
# |    n_updates       | 8383     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -7e+03   |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 100      |
# |    time_elapsed    | 88       |
# |    total_timesteps | 8888     |
# | train/             |          |
# |    actor_loss      | 1.99e+03 |
# |    critic_loss     | 133      |
# |    learning_rate   | 0.0005   |
# |    n_updates       | 8787     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -7e+03   |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 100      |
# |    time_elapsed    | 92       |
# |    total_timesteps | 9292     |
# | train/             |          |
# |    actor_loss      | 2.06e+03 |
# |    critic_loss     | 134      |
# |    learning_rate   | 0.0005   |
# |    n_updates       | 9191     |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 101       |
# |    ep_rew_mean     | -6.97e+03 |
# | time/              |           |
# |    episodes        | 96        |
# |    fps             | 100       |
# |    time_elapsed    | 96        |
# |    total_timesteps | 9696      |
# | train/             |           |
# |    actor_loss      | 2.13e+03  |
# |    critic_loss     | 137       |
# |    learning_rate   | 0.0005    |
# |    n_updates       | 9595      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 101       |
# |    ep_rew_mean     | -6.96e+03 |
# | time/              |           |
# |    episodes        | 100       |
# |    fps             | 100       |
# |    time_elapsed    | 100       |
# |    total_timesteps | 10100     |
# | train/             |           |
# |    actor_loss      | 2.19e+03  |
# |    critic_loss     | 120       |
# |    learning_rate   | 0.0005    |
# |    n_updates       | 9999      |
# ----------------------------------

# %%
from stable_baselines3.common.evaluation import evaluate_policy
ddpg_model = sb3.DDPG.load("./model/double_pendulum_ddpg.zip")
mean_reward, std_reward = evaluate_policy(ddpg_model, test_env, n_eval_episodes=10, render=True)
print("mean_reward:",mean_reward,"std_reward:",std_reward)
# Out:
# /home/marunyu/.cache/pypoetry/virtualenvs/eagerx-izmxb-y5-py3.9/lib/python3.9/site-packages/stable_baselines3/common/evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
#
# QObject::moveToThread: Current thread (0x7f45f4001770) is not the object's thread (0x7f45f41251a0).
# Cannot move to target thread (0x7f45f4001770)
# mean_reward: -16366.063647460938 std_reward: 715.1643758213144

# %% [markdown]
# # 2.3 PPO

# %%
ppo_model = sb3.PPO("MlpPolicy", train_env, verbose=1, learning_rate=5e-4, tensorboard_log="./tensorboard/ppo_doupen_tensorboard/")
train_env.render("human")
ppo_model.learn(total_timesteps=int(10000))
train_env.close()
ddpg_model.save("./model/double_pendulum_ppo")
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to ./tensorboard/ppo_doupen_tensorboard/PPO_1
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 101       |
# |    ep_rew_mean     | -1.08e+04 |
# | time/              |           |
# |    fps             | 129       |
# |    iterations      | 1         |
# |    time_elapsed    | 15        |
# |    total_timesteps | 2048      |
# ----------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 3
#       1 ppo_model = sb3.PPO("MlpPolicy", train_env, verbose=1, learning_rate=5e-4, tensorboard_log="./tensorboard/ppo_doupen_tensorboard/")
#       2 train_env.render("human")
# ----> 3 ppo_model.learn(total_timesteps=int(10000))
#       4 train_env.close()
#       5 ddpg_model.save("./model/double_pendulum_ppo")
#
# File ~/.cache/pypoetry/virtualenvs/eagerx-izmxb-y5-py3.9/lib/python3.9/site-packages/stable_baselines3/ppo/ppo.py:317, in PPO.learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps, progress_bar)
#     303 def learn(
#     304     self: PPOSelf,
#     305     total_timesteps: int,
#    (...)
#     314     progress_bar: bool = False,
#     315 ) -> PPOSelf:
# --> 317     return super().learn(
#     318         total_timesteps=total_timesteps,
#     319         callback=callback,
#     320         log_interval=log_interval,
#     321         eval_env=eval_env,
#     322         eval_freq=eval_freq,
#     323         n_eval_episodes=n_eval_episodes,
#     324         tb_log_name=tb_log_name,
#     325         eval_log_path=eval_log_path,
#     326         reset_num_timesteps=reset_num_timesteps,
#     327         progress_bar=progress_bar,
#     328     )
#
# File ~/.cache/pypoetry/virtualenvs/eagerx-izmxb-y5-py3.9/lib/python3.9/site-packages/stable_baselines3/common/on_policy_algorithm.py:262, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps, progress_bar)
#     258 callback.on_training_start(locals(), globals())
#     260 while self.num_timesteps < total_timesteps:
# --> 262     continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     264     if continue_training is False:
#     265         break
#
# File ~/.cache/pypoetry/virtualenvs/eagerx-izmxb-y5-py3.9/lib/python3.9/site-packages/stable_baselines3/common/on_policy_algorithm.py:210, in OnPolicyAlgorithm.collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     207             terminal_value = self.policy.predict_values(terminal_obs)[0]
#     208         rewards[idx] += self.gamma * terminal_value
# --> 210 rollout_buffer.add(self._last_obs, actions, rewards, self._last_episode_starts, values, log_probs)
#     211 self._last_obs = new_obs
#     212 self._last_episode_starts = dones
#
# File ~/.cache/pypoetry/virtualenvs/eagerx-izmxb-y5-py3.9/lib/python3.9/site-packages/stable_baselines3/common/buffers.py:440, in RolloutBuffer.add(self, obs, action, reward, episode_start, value, log_prob)
#     437 action = action.reshape((self.n_envs, self.action_dim))
#     439 self.observations[self.pos] = np.array(obs).copy()
# --> 440 self.actions[self.pos] = np.array(action).copy()
#     441 self.rewards[self.pos] = np.array(reward).copy()
#     442 self.episode_starts[self.pos] = np.array(episode_start).copy()
#
# KeyboardInterrupt:

# %%
from stable_baselines3.common.evaluation import evaluate_policy
ppo_model = sb3.DDPG.load("./model/double_pendulum_ppo.zip")
mean_reward, std_reward = evaluate_policy(ppo_model, test_env, n_eval_episodes=10, render=True)
print("mean_reward:",mean_reward,"std_reward:",std_reward)
